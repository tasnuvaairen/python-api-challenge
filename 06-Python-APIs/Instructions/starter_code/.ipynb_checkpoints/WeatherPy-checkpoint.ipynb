# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import urllib

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities2.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["deg"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 2 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=butaritari
# Processing Record 3 of Set 1 | cabatuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cabatuan
# Processing Record 4 of Set 1 | oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=oga
# Processing Record 5 of Set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sao%20joao%20da%20barra
# Processing Record 6 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bredasdorp
# Processing Record 7 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hermanus
# Processing Record 8 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nikolskoye
# Processing Record 9 of Set 1 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tezu
# Processing Record 10 of Set 1 | mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mbekenyera
# Processing Record 11 of Set 1 | novopokrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=novopokrovka
# Processing Record 12 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saint%20george
# Processing Record 13 of Set 1 | rypefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=rypefjord
# Processing Record 14 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=rikitea
# Processing Record 15 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=coquimbo
# Processing Record 16 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jamestown
# Processing Record 17 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pisco
# Processing Record 18 of Set 1 | orocue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=orocue
# Processing Record 19 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=atuona
# Processing Record 20 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20hardy
# Processing Record 21 of Set 1 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=vardo
# Processing Record 22 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kapaa
# Processing Record 23 of Set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=charters%20towers
# Processing Record 24 of Set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dingle
# Processing Record 25 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=torbay
# Processing Record 26 of Set 1 | santa maria da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=santa%20maria%20da%20vitoria
# Processing Record 27 of Set 1 | jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jasper
# Processing Record 28 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saint%20anthony
# Processing Record 29 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=puerto%20ayora
# Processing Record 30 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=yellowknife
# Processing Record 31 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ribeira%20grande
# Processing Record 32 of Set 1 | gannan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=gannan
# Processing Record 33 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hambantota
# Processing Record 34 of Set 1 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=college
# Processing Record 35 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=airai
# Processing Record 36 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=provideniya
# Processing Record 38 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tuktoyaktuk
# Processing Record 39 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saint-philippe
# Processing Record 40 of Set 1 | ohara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ohara
# Processing Record 41 of Set 1 | sandnessjoen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sandnessjoen
# Processing Record 42 of Set 1 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dunedin
# Processing Record 43 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=iqaluit
# Processing Record 44 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=albany
# Processing Record 45 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ushuaia
# Processing Record 46 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=arraial%20do%20cabo
# Processing Record 47 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=qaanaaq
# Processing Record 48 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=avarua
# Processing Record 49 of Set 1 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=walvis%20bay
# Processing Record 50 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=vaini
# Processing Record 0 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=udachnyy
# Processing Record 2 of Set 2 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=karaul
# City not found. Skipping...
# Processing Record 3 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=severo-kurilsk
# Processing Record 4 of Set 2 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tabou
# Processing Record 5 of Set 2 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tura
# Processing Record 6 of Set 2 | pervomayskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pervomayskoye
# Processing Record 7 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mar%20del%20plata
# Processing Record 8 of Set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=salalah
# Processing Record 9 of Set 2 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cayenne
# Processing Record 10 of Set 2 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=muravlenko
# Processing Record 11 of Set 2 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=elko
# Processing Record 12 of Set 2 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sistranda
# Processing Record 13 of Set 2 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=touros
# Processing Record 14 of Set 2 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dauphin
# Processing Record 15 of Set 2 | do gonbadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=do%20gonbadan
# Processing Record 16 of Set 2 | goba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=goba
# Processing Record 17 of Set 2 | golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=golden
# Processing Record 18 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=new%20norfolk
# Processing Record 19 of Set 2 | carroll
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=carroll
# Processing Record 20 of Set 2 | chimoio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=chimoio
# Processing Record 21 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=vila%20franca%20do%20campo
# Processing Record 22 of Set 2 | jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jalingo
# Processing Record 23 of Set 2 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lazaro%20cardenas
# Processing Record 24 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=punta%20arenas
# Processing Record 25 of Set 2 | novaya igirma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=novaya%20igirma
# Processing Record 26 of Set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tuatapere
# Processing Record 27 of Set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kavieng
# Processing Record 28 of Set 2 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=harper
# Processing Record 29 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20alfred
# Processing Record 30 of Set 2 | kozhva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kozhva
# Processing Record 31 of Set 2 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=upata
# Processing Record 32 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=narsaq
# Processing Record 33 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jinchang
# Processing Record 35 of Set 2 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=gat
# Processing Record 36 of Set 2 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=maniitsoq
# Processing Record 37 of Set 2 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tarko-sale
# Processing Record 38 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kavaratti
# Processing Record 39 of Set 2 | baker city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=baker%20city
# Processing Record 40 of Set 2 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=khonuu
# City not found. Skipping...
# Processing Record 41 of Set 2 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ishigaki
# Processing Record 42 of Set 2 | aktau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=aktau
# Processing Record 43 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port-gentil
# Processing Record 44 of Set 2 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=alice%20springs
# Processing Record 45 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ponta%20do%20sol
# Processing Record 46 of Set 2 | longlac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=longlac
# City not found. Skipping...
# Processing Record 47 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=flinders
# Processing Record 48 of Set 2 | severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=severodvinsk
# Processing Record 49 of Set 2 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=severo-yeniseyskiy
# Processing Record 0 of Set 3 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kiama
# Processing Record 1 of Set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=avera
# Processing Record 2 of Set 3 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=aswan
# Processing Record 3 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bluff
# Processing Record 4 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=constitucion
# Processing Record 5 of Set 3 | otane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=otane
# Processing Record 6 of Set 3 | okitipupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=okitipupa
# Processing Record 7 of Set 3 | alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=alotau
# City not found. Skipping...
# Processing Record 8 of Set 3 | barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=barra%20patuca
# Processing Record 9 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ilulissat
# Processing Record 10 of Set 3 | xingtai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=xingtai
# Processing Record 11 of Set 3 | dawson creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dawson%20creek
# City not found. Skipping...
# Processing Record 12 of Set 3 | estelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=estelle
# Processing Record 13 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=thompson
# Processing Record 14 of Set 3 | madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=madang
# Processing Record 15 of Set 3 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=busselton
# Processing Record 16 of Set 3 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=broome
# Processing Record 17 of Set 3 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=taltal
# Processing Record 18 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bethel
# Processing Record 19 of Set 3 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=muros
# Processing Record 20 of Set 3 | cotonou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cotonou
# Processing Record 21 of Set 3 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sept-iles
# Processing Record 22 of Set 3 | miguel hidalgo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=miguel%20hidalgo
# Processing Record 23 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=upernavik
# Processing Record 24 of Set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bathsheba
# Processing Record 25 of Set 3 | masuguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=masuguru
# Processing Record 26 of Set 3 | palampur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=palampur
# Processing Record 27 of Set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 3 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bargal
# City not found. Skipping...
# Processing Record 30 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=castro
# Processing Record 31 of Set 3 | diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=diamantino
# Processing Record 32 of Set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pacific%20grove
# Processing Record 33 of Set 3 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=coahuayana
# Processing Record 34 of Set 3 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ketchikan
# Processing Record 35 of Set 3 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tomatlan
# Processing Record 36 of Set 3 | dera din panah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dera%20din%20panah
# City not found. Skipping...
# Processing Record 37 of Set 3 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=itarema
# Processing Record 38 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=meulaboh
# Processing Record 39 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kaitangata
# Processing Record 40 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=khatanga
# Processing Record 41 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=georgetown
# Processing Record 42 of Set 3 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=abu%20dhabi
# Processing Record 43 of Set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=east%20london
# Processing Record 44 of Set 3 | nan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nan
# Processing Record 45 of Set 3 | port arthur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20arthur
# Processing Record 46 of Set 3 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=seoul
# Processing Record 47 of Set 3 | payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=payo
# Processing Record 48 of Set 3 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ryotsu
# City not found. Skipping...
# Processing Record 49 of Set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kruisfontein
# Processing Record 0 of Set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=honiara
# Processing Record 1 of Set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pangnirtung
# Processing Record 2 of Set 4 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mataura
# Processing Record 3 of Set 4 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=manokwari
# Processing Record 4 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20lincoln
# Processing Record 5 of Set 4 | concepcion del oro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=concepcion%20del%20oro
# Processing Record 6 of Set 4 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=karratha
# Processing Record 7 of Set 4 | muvattupula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=muvattupula
# Processing Record 8 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tiksi
# Processing Record 9 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cidreira
# Processing Record 10 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dikson
# Processing Record 11 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=codrington
# Processing Record 12 of Set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=barrow
# Processing Record 14 of Set 4 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hilo
# Processing Record 15 of Set 4 | salur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=salur
# Processing Record 16 of Set 4 | kemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kemi
# Processing Record 17 of Set 4 | lundazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lundazi
# Processing Record 18 of Set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cherskiy
# Processing Record 19 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lebu
# Processing Record 20 of Set 4 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saint-francois
# Processing Record 21 of Set 4 | romitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=romitan
# Processing Record 22 of Set 4 | weston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=weston
# Processing Record 23 of Set 4 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=longyearbyen
# Processing Record 24 of Set 4 | humboldt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=humboldt
# Processing Record 25 of Set 4 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=san%20patricio
# Processing Record 26 of Set 4 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=belushya%20guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nosy%20varika
# Processing Record 28 of Set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ostrovnoy
# Processing Record 29 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=victoria
# Processing Record 30 of Set 4 | birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=birjand
# Processing Record 31 of Set 4 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kodiak
# Processing Record 33 of Set 4 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kulhudhuffushi
# Processing Record 34 of Set 4 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=grindavik
# Processing Record 35 of Set 4 | kencong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kencong
# Processing Record 36 of Set 4 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sabang
# Processing Record 37 of Set 4 | lannion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lannion
# Processing Record 38 of Set 4 | jodhpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jodhpur
# Processing Record 39 of Set 4 | hanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hanna
# Processing Record 40 of Set 4 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sisimiut
# Processing Record 41 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cape%20town
# Processing Record 42 of Set 4 | general pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=general%20pico
# Processing Record 43 of Set 4 | moissala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=moissala
# Processing Record 44 of Set 4 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=jalu
# Processing Record 45 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hithadhoo
# Processing Record 46 of Set 4 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=beringovskiy
# Processing Record 47 of Set 4 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bowen
# Processing Record 48 of Set 4 | casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=casper
# Processing Record 49 of Set 4 | kibala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kibala
# Processing Record 0 of Set 5 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=matara
# Processing Record 1 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mahebourg
# Processing Record 2 of Set 5 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=maarianhamina
# City not found. Skipping...
# Processing Record 4 of Set 5 | tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tarakan
# Processing Record 5 of Set 5 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tasiilaq
# Processing Record 6 of Set 5 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=porto%20novo
# Processing Record 7 of Set 5 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=katsuura
# Processing Record 8 of Set 5 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=katangli
# Processing Record 9 of Set 5 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pevek
# Processing Record 10 of Set 5 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=paamiut
# Processing Record 11 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20elizabeth
# Processing Record 12 of Set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lompoc
# Processing Record 13 of Set 5 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=shieli
# Processing Record 14 of Set 5 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mareeba
# Processing Record 15 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bengkulu
# City not found. Skipping...
# Processing Record 16 of Set 5 | medicine hat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=medicine%20hat
# Processing Record 17 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hofn
# Processing Record 18 of Set 5 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=qasigiannguit
# Processing Record 19 of Set 5 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=te%20anau
# Processing Record 20 of Set 5 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=port%20augusta
# Processing Record 21 of Set 5 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mitu
# Processing Record 22 of Set 5 | tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tahoua
# Processing Record 23 of Set 5 | mufumbwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mufumbwe
# Processing Record 24 of Set 5 | arang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=arang
# Processing Record 25 of Set 5 | bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bacolod
# Processing Record 26 of Set 5 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=faya
# Processing Record 27 of Set 5 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=turukhansk
# Processing Record 28 of Set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saskylakh
# Processing Record 29 of Set 5 | sarab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sarab
# Processing Record 30 of Set 5 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=auki
# Processing Record 31 of Set 5 | muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=muzhi
# Processing Record 32 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=norman%20wells
# Processing Record 33 of Set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=guerrero%20negro
# Processing Record 34 of Set 5 | la gaulette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=la%20gaulette
# City not found. Skipping...
# Processing Record 35 of Set 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=luderitz
# Processing Record 36 of Set 5 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=buraydah
# Processing Record 37 of Set 5 | tananger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tananger
# Processing Record 38 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 5 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nemuro
# Processing Record 40 of Set 5 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bubaque
# Processing Record 41 of Set 5 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sambava
# Processing Record 42 of Set 5 | chebsara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=chebsara
# Processing Record 43 of Set 5 | teeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=teeli
# Processing Record 44 of Set 5 | yuzhne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=yuzhne
# Processing Record 45 of Set 5 | price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=price
# Processing Record 46 of Set 5 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=warqla
# City not found. Skipping...
# Processing Record 47 of Set 5 | groningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=groningen
# Processing Record 48 of Set 5 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kudahuvadhoo
# Processing Record 49 of Set 5 | southbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=southbridge
# Processing Record 0 of Set 6 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=geraldton
# Processing Record 1 of Set 6 | lhuntshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lhuntshi
# City not found. Skipping...
# Processing Record 2 of Set 6 | canitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=canitas
# City not found. Skipping...
# Processing Record 3 of Set 6 | mascali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mascali
# Processing Record 4 of Set 6 | andilamena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=andilamena
# Processing Record 5 of Set 6 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=carnarvon
# Processing Record 6 of Set 6 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nouadhibou
# Processing Record 7 of Set 6 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=caravelas
# Processing Record 8 of Set 6 | sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sao%20miguel%20do%20araguaia
# Processing Record 9 of Set 6 | sao raimundo das mangabeiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sao%20raimundo%20das%20mangabeiras
# Processing Record 10 of Set 6 | abbeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=abbeville
# Processing Record 11 of Set 6 | la peca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=la%20peca
# Processing Record 12 of Set 6 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dwarka
# Processing Record 13 of Set 6 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=myitkyina
# Processing Record 14 of Set 6 | bayangol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bayangol
# Processing Record 15 of Set 6 | allanridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=allanridge
# Processing Record 16 of Set 6 | lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lingao
# Processing Record 17 of Set 6 | sembakung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sembakung
# Processing Record 18 of Set 6 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=evensk
# Processing Record 19 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saldanha
# Processing Record 20 of Set 6 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=asau
# City not found. Skipping...
# Processing Record 21 of Set 6 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=souillac
# Processing Record 22 of Set 6 | aden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=aden
# Processing Record 23 of Set 6 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sioux%20lookout
# Processing Record 24 of Set 6 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=antofagasta
# Processing Record 25 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=clyde%20river
# Processing Record 26 of Set 6 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=necochea
# Processing Record 27 of Set 6 | zhanjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=zhanjiang
# Processing Record 28 of Set 6 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=plettenberg%20bay
# Processing Record 29 of Set 6 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=belmonte
# Processing Record 30 of Set 6 | sainte-anne-des-monts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sainte-anne-des-monts
# Processing Record 31 of Set 6 | riverton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=riverton
# Processing Record 32 of Set 6 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=esperance
# Processing Record 33 of Set 6 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=margate
# Processing Record 34 of Set 6 | kyren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kyren
# Processing Record 35 of Set 6 | khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=khash
# Processing Record 36 of Set 6 | podporozhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=podporozhye
# Processing Record 37 of Set 6 | kheri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kheri
# Processing Record 38 of Set 6 | llanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=llanes
# Processing Record 39 of Set 6 | mbanza-ngungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mbanza-ngungu
# Processing Record 40 of Set 6 | altamira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=altamira
# Processing Record 41 of Set 6 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=fukue
# Processing Record 43 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hasaki
# Processing Record 44 of Set 6 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tuy%20hoa
# Processing Record 45 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sitka
# Processing Record 46 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cabo%20san%20lucas
# Processing Record 47 of Set 6 | aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=aloleng
# Processing Record 48 of Set 6 | liwale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=liwale
# Processing Record 49 of Set 6 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=naze
# Processing Record 0 of Set 7 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=hobart
# Processing Record 1 of Set 7 | dire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=dire
# Processing Record 2 of Set 7 | coari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=coari
# Processing Record 3 of Set 7 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bambous%20virieux
# Processing Record 4 of Set 7 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=oranjestad
# Processing Record 5 of Set 7 | governador valadares
# ...
# Processing Record 24 of Set 11 | merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=merrill
# Processing Record 25 of Set 11 | sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sumbe
# Processing Record 26 of Set 11 | cumra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cumra
# Processing Record 27 of Set 11 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=taksimo
# Processing Record 28 of Set 11 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 11 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=puri
# Processing Record 30 of Set 11 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=korla
# City not found. Skipping...
# Processing Record 31 of Set 11 | pisek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pisek
# Processing Record 32 of Set 11 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nguiu
# City not found. Skipping...
# Processing Record 33 of Set 11 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=aykhal
# Processing Record 34 of Set 11 | nanchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nanchang
# Processing Record 35 of Set 11 | mvuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mvuma
# Processing Record 36 of Set 11 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=cururupu
# Processing Record 37 of Set 11 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bilibino
# Processing Record 38 of Set 11 | erdenet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=erdenet
# Processing Record 39 of Set 11 | maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=maningrida
# Processing Record 40 of Set 11 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=klaksvik
# Processing Record 41 of Set 11 | saquarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=saquarema
# Processing Record 42 of Set 11 | englehart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=englehart
# Processing Record 43 of Set 11 | slave lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=slave%20lake
# Processing Record 44 of Set 11 | mahanoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mahanoro
# Processing Record 45 of Set 11 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=chagda
# City not found. Skipping...
# Processing Record 46 of Set 11 | tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tucuman
# Processing Record 47 of Set 11 | waverly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=waverly
# Processing Record 48 of Set 11 | mustasaari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mustasaari
# Processing Record 49 of Set 11 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=alofi
# Processing Record 0 of Set 12 | allanmyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=allanmyo
# City not found. Skipping...
# Processing Record 1 of Set 12 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=maldonado
# Processing Record 2 of Set 12 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=igarka
# Processing Record 3 of Set 12 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=husavik
# Processing Record 4 of Set 12 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=champerico
# Processing Record 5 of Set 12 | kirando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kirando
# Processing Record 6 of Set 12 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=progreso
# Processing Record 7 of Set 12 | foz do iguacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=foz%20do%20iguacu
# Processing Record 8 of Set 12 | makali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=makali
# Processing Record 9 of Set 12 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=namibe
# Processing Record 10 of Set 12 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=flin%20flon
# Processing Record 11 of Set 12 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tres%20arroyos
# Processing Record 12 of Set 12 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=opuwo
# Processing Record 13 of Set 12 | manakara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=manakara
# Processing Record 14 of Set 12 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=balkhash
# Processing Record 15 of Set 12 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kununurra
# Processing Record 16 of Set 12 | boksitogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=boksitogorsk
# Processing Record 17 of Set 12 | niono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=niono
# Processing Record 18 of Set 12 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=vao
# Processing Record 19 of Set 12 | storforshei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=storforshei
# City not found. Skipping...
# Processing Record 20 of Set 12 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kalmunai
# Processing Record 21 of Set 12 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=alta%20floresta
# Processing Record 22 of Set 12 | omura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=omura
# Processing Record 23 of Set 12 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=muroto
# Processing Record 24 of Set 12 | yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=yangambi
# Processing Record 25 of Set 12 | mazara del vallo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mazara%20del%20vallo
# Processing Record 26 of Set 12 | america dourada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=america%20dourada
# Processing Record 27 of Set 12 | lumeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=lumeje
# Processing Record 28 of Set 12 | nagato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=nagato
# City not found. Skipping...
# Processing Record 29 of Set 12 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sao%20filipe
# Processing Record 30 of Set 12 | statesboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=statesboro
# Processing Record 31 of Set 12 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=bandarbeyla
# Processing Record 32 of Set 12 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=mecca
# Processing Record 33 of Set 12 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=morondava
# Processing Record 34 of Set 12 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ust-kuyga
# Processing Record 35 of Set 12 | tarabuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tarabuco
# Processing Record 36 of Set 12 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=oistins
# Processing Record 37 of Set 12 | ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ibra
# Processing Record 38 of Set 12 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=roald
# Processing Record 39 of Set 12 | pancas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pancas
# Processing Record 40 of Set 12 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=waingapu
# Processing Record 41 of Set 12 | kennett
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kennett
# Processing Record 42 of Set 12 | maubin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=maubin
# Processing Record 43 of Set 12 | syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=syracuse
# Processing Record 44 of Set 12 | high rock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=high%20rock
# Processing Record 45 of Set 12 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=shingu
# Processing Record 46 of Set 12 | belle fourche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=belle%20fourche
# Processing Record 47 of Set 12 | buga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=buga
# Processing Record 48 of Set 12 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=marystown
# Processing Record 49 of Set 12 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=henties%20bay
# Processing Record 0 of Set 13 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=buala
# Processing Record 1 of Set 13 | puerto cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=puerto%20cabezas
# Processing Record 2 of Set 13 | garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=garissa
# Processing Record 3 of Set 13 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=sur
# Processing Record 4 of Set 13 | naantali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=naantali
# Processing Record 5 of Set 13 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=abu%20kamal
# Processing Record 6 of Set 13 | indramayu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=indramayu
# Processing Record 7 of Set 13 | kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kayerkan
# Processing Record 8 of Set 13 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=rio%20cuarto
# Processing Record 9 of Set 13 | davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=davila
# Processing Record 10 of Set 13 | korfovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=korfovskiy
# City not found. Skipping...
# Processing Record 11 of Set 13 | santarem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=santarem
# City not found. Skipping...
# Processing Record 12 of Set 13 | houston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=houston
# Processing Record 13 of Set 13 | yurimaguas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=yurimaguas
# Processing Record 14 of Set 13 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=peniche
# Processing Record 15 of Set 13 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=pacifica
# Processing Record 16 of Set 13 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 13 | baoning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=baoning
# Processing Record 18 of Set 13 | vung tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=vung%20tau
# Processing Record 19 of Set 13 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=fairbanks
# Processing Record 20 of Set 13 | ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=ilebo
# Processing Record 21 of Set 13 | krasnokamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=krasnokamensk
# Processing Record 22 of Set 13 | anakapalle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=anakapalle
# Processing Record 23 of Set 13 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=tautira
# Processing Record 24 of Set 13 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11e94744268503e2746a35fa130d874f&q=road%20town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_data)

lat = city_df["Lat"]
lng = city_df["Lng"]
max_temp = city_df["Max Temp"]
humidity=city_df["Humidity"]
cloudiness = city_df["Cloudiness"]
wind_speed = city_df["Wind Speed"]

city_df.to_csv(output_data_file,index_label="city_ID")

city_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
city_df
# Out:
#                   City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           butaritari   3.07  172.79     84.06        80         100
# 1             cabatuan  16.95  121.67     71.46        86         100
# 2                  oga  46.46   10.35     36.00        67           5
# 3    sao joao da barra -21.64  -41.05     91.40        55          40
# 4           bredasdorp -34.53   20.04     69.80        52         100
# ..                 ...    ...     ...       ...       ...         ...
# 560              ilebo  -4.33   20.59     85.80        55          98
# 561      krasnokamensk  50.10  118.04      9.90        96          97
# 562         anakapalle  17.69   83.00     75.20        78          75
# 563            tautira -17.73 -149.15     77.00        88          20
# 564          road town  18.42  -64.62     80.60        74          75
#
#      Wind Speed Country        Date
# 0            80      KI  1578327810
# 1           268      PH  1578327810
# 2           337      IT  1578327810
# 3            53      BR  1578327649
# 4           220      ZA  1578327610
# ..          ...     ...         ...
# 560          41      CD  1578327858
# 561         351      RU  1578327858
# 562          60      IN  1578327858
# 563         110      PF  1578327858
# 564          60      VG  1578327858
#
# [565 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_df["Lat"],city_df["Max Temp"],facecolors="lightblue",edgecolors="black" ,marker="o", s=35, alpha= 1)
plt.title("City Latitude vs. Max Temperature (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Lat"],city_df["Humidity"],facecolors="lightblue",edgecolors="black",marker="o", s=35, alpha= 1)
plt.title("City Latitude vs. Humidity (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0, 300)
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Lat"],city_df["Cloudiness"],facecolors="lightblue",edgecolors="black",marker="o", s=35, alpha= 1)
plt.title("City Latitude vs. Cloudiness (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Lat"],city_df["Wind Speed"],facecolors="lightblue",edgecolors="black",marker="o", s=35, alpha= 1)
plt.title("City Latitude vs. Wind Speed (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(plt, x, y, color) :
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    plt.plot(x, intercept + slope*x, color)

# %%
# Create Northern and Southern Hemisphere DataFrames
# Create Northern and Southern Hemisphere DataFrames
nh_city_df = city_df[city_df["Lat"]>=0].copy()
#print("Northern Hemisphere")
#print(nh_city_df.count())
sh_city_df = city_df[city_df["Lat"]<0].copy()
#print("Southern Hemisphere")
#print(sh_city_df.count())

#slope, intercept, r_value, p_value, std_err = linregress(nh_city_df["Lat"], nh_city_df["Max Temp"])
#print(slope)
#print(intercept)
#print(r_value)
#print(p_value)
#print(std_err)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(nh_city_df["Lat"],nh_city_df["Max Temp"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(nh_city_df["Lat"], intercept + slope*nh_city_df["Lat"], 'r')
plot_linear_regression(plt, nh_city_df["Lat"], nh_city_df["Max Temp"], 'r')
plt.title("NH City Latitude vs. Max Temperature (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig5.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(sh_city_df["Lat"],sh_city_df["Max Temp"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(sh_city_df["Lat"], intercept + slope*sh_city_df["Lat"], 'r')
plot_linear_regression(plt, sh_city_df["Lat"], sh_city_df["Max Temp"], 'r')
plt.title("SH City Latitude vs. Max Temperature (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig6.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(nh_city_df["Lat"],nh_city_df["Humidity"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(nh_city_df["Lat"], intercept + slope*nh_city_df["Lat"], 'r')
plot_linear_regression(plt, nh_city_df["Lat"], nh_city_df["Humidity"], 'r')
plt.title("NH City Latitude vs. Humidity (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,300)
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig7.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(sh_city_df["Lat"],sh_city_df["Humidity"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(sh_city_df["Lat"], intercept + slope*sh_city_df["Lat"], 'r')
plot_linear_regression(plt, sh_city_df["Lat"], sh_city_df["Humidity"], 'r')
plt.title("SH City Latitude vs. Humidity (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0, 300)
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig8.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(nh_city_df["Lat"],nh_city_df["Cloudiness"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(nh_city_df["Lat"], intercept + slope*nh_city_df["Lat"], 'r')
plot_linear_regression(plt, nh_city_df["Lat"], nh_city_df["Cloudiness"], 'r')
plt.title("NH City Latitude vs. Cloudiness (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig9.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(sh_city_df["Lat"],sh_city_df["Cloudiness"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(sh_city_df["Lat"], intercept + slope*sh_city_df["Lat"], 'r')
plot_linear_regression(plt, sh_city_df["Lat"], sh_city_df["Cloudiness"], 'r')
plt.title("SH City Latitude vs. Cloudiness (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig10.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(nh_city_df["Lat"],nh_city_df["Wind Speed"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(nh_city_df["Lat"], intercept + slope*nh_city_df["Lat"], 'r')
plot_linear_regression(plt, nh_city_df["Lat"], nh_city_df["Wind Speed"], 'r')
plt.title("NH City Latitude vs. Wind Speed (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig11.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(sh_city_df["Lat"],sh_city_df["Wind Speed"],facecolors="lightblue",
edgecolors="black" ,marker="o", s=35, alpha= 1)
#plt.plot(sh_city_df["Lat"], intercept + slope*sh_city_df["Lat"], 'r')
plot_linear_regression(plt, sh_city_df["Lat"], sh_city_df["Wind Speed"], 'r')
plt.title("SH City Latitude vs. Wind Speed (12/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-")
plt.savefig("output_data/city_df_fig12.png")
plt.show()
